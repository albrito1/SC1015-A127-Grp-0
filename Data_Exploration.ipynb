# %% [markdown]
# # <left>  Data Exploration

# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()

import warnings 
warnings.filterwarnings('ignore')

# %%
#Importing dataset
df = pd.read_csv('Walmart.csv')

#Display raw data
display(df.head())
original_df = df.copy(deep=True)

print('\n\033[1mInference:\033[0m The Datset consists of {} headers & {} samples.'.format(df.shape[1], df.shape[0]))
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# Inference: The Datset consists of 8 headers & 6435 samples.

# %%
#Distribute the column "Date" into 3 sections -> "weekday", "month" & "year"
df.Date=pd.to_datetime(df.Date)

df['day'] = df.Date.dt.weekday
df['month'] = df.Date.dt.month
df['year'] = df.Date.dt.year

# df['Monthly_Quarter'] = df.month.map({1:'Q1',2:'Q1',3:'Q1',4:'Q2',5:'Q2',6:'Q2',7:'Q3',
#                                       8:'Q3',9:'Q3',10:'Q4',11:'Q4',12:'Q4'})

df.drop(['Date'], axis=1, inplace=True)#,'month'
original_df = df.copy(deep=True)

df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  day  month  year
# 0         8.106    6      5  2010
# 1         8.106    3     12  2010
# 2         8.106    4      2  2010
# 3         8.106    4      2  2010
# 4         8.106    0      5  2010

# %%
#Check column Dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Weekly_Sales  6435 non-null   float64
#  2   Holiday_Flag  6435 non-null   int64
#  3   Temperature   6435 non-null   float64
#  4   Fuel_Price    6435 non-null   float64
#  5   CPI           6435 non-null   float64
#  6   Unemployment  6435 non-null   float64
#  7   day           6435 non-null   int64
#  8   month         6435 non-null   int64
#  9   year          6435 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 502.9 KB

# %%
#Check number of unique rows
df.nunique().sort_values()
# Out:
# Holiday_Flag       2
# year               3
# day                7
# month             12
# Store             45
# Unemployment     349
# Fuel_Price       892
# CPI             2145
# Temperature     3528
# Weekly_Sales    6435
# dtype: int64

# %% [markdown]
# ```
# Holiday_Flag = 1 or 0
# ```
#
#
# ```
# Year = 2010, 2011, 2012
# ```
#
#
# ```
# Store = 45 distinct stores in US
# ```
#
#
# ```
# CPI = Consumer price index
# ```

# %%
#Check stats
display(df.describe())
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment          day        month         year
# count  6435.000000   6435.000000  6435.000000  6435.000000  6435.000000
# mean    171.578394      7.999151     3.573427     6.475524  2010.965035
# std      39.356712      1.875885     1.426581     3.321797     0.797019
# ...

# %% [markdown]
# # <left>  Exploratory Data Analysis

# %%
#Checking number of unique rows in each feature
import math
import matplotlib.pyplot as plt

target = 'Weekly_Sales'
features = [i for i in df.columns if i not in [target]]

nu = df[features].nunique().sort_values()
nf = []; cf = [];nnf = 0; ncf = 0;  #numerical & categorical features

for i in range(df[features].shape[1]):
    if nu.values[i]<=45:cf.append(nu.index[i])
    else: nf.append(nu.index[i])

print('\n\033[1mInference:\033[0m The Datset has {} numerical & {} categorical features.'.format(len(nf),len(cf)))
# Out:
# Inference: The Datset has 4 numerical & 5 categorical features.

# %%
plt.figure(figsize=[8,4])
sb.distplot(df[target], color='g',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Target Variable Distribution')
plt.show()

# %%
# Visualising the categorical features
print('\033[1mVisualising Categorical Features:'.center(100))

num_cols = 2  # number of columns in each row
num_rows = 2

fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 8))
axs = axs.flatten()

sb.countplot(x=cf[0], data=df, ax=axs[0])
sb.countplot(x=cf[1], data=df, ax=axs[1])
sb.countplot(x=cf[2], data=df, ax=axs[2])
sb.countplot(x=cf[3], data=df, ax=axs[3])

    
plt.tight_layout()
plt.show()
# Out:
#                                Visualising Categorical Features:

# %%
#Visualising the numeric features 

print('\033[1mNumeric Features Distribution'.center(130))

n=4

clr=['r','g','b','g','b','r']

plt.figure(figsize=[15,6*math.ceil(len(nf)/n)])
for i in range(len(nf)):
    plt.subplot(math.ceil(len(nf)/3),n,i+1)
    sb.distplot(df[nf[i]],hist_kws=dict(edgecolor="black", linewidth=2), bins=10, color=list(np.random.randint([255,255,255])/255))
plt.tight_layout()

plt.show()

plt.figure(figsize=[15,6*math.ceil(len(nf)/n)])
for i in range(len(nf)):
    plt.subplot(math.ceil(len(nf)/3),n,i+1)
    df.boxplot(nf[i])
plt.tight_layout()
plt.show()
# Out:
#                                                 Numeric Features Distribution

# %%
#Relationship between all the features compared against Weekly_Sales

g = sb.pairplot(data=df,
                y_vars=['Weekly_Sales'],
                x_vars=['Store', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'day', 'month', 'year'])
plt.title('Pairplots for all the Feature')
g.map_upper(sb.kdeplot, levels=4, color=".2")
plt.show()

# %%
df.to_csv("Walmart_E.csv")
